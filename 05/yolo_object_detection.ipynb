# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt') 
results = model.train(data='balloon.v1i.yolov8/data.yaml', epochs=100)
# Out:
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.12 torch-2.0.1+cu117 CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# ...

# %%
results

# %%
results = model.val()
results
# Out:
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.12 torch-2.0.1+cu117 CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# val: Scanning /home/florian/projects/fh/mc/semester3/dnn/datasets/balloon.v1i.yolov8/valid/labels.cache... 13 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13/13 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
#                    all         13         50      0.948        0.7      0.799      0.689
# Speed: 0.8ms preprocess, 49.5ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /home/florian/projects/fh/mc/semester3/dnn/lab/runs/detect/val2

# %%
model('https://ichef.bbci.co.uk/news/976/cpsprodpb/C7DD/production/_97256115_mediaitem97256111.jpg')
# Out:
# ...
# 100%|██████████| 115k/115k [00:00<00:00, 5.66MB/s]
# image 1/1 /home/florian/projects/fh/mc/semester3/dnn/lab/05/_97256115_mediaitem97256111.jpg: 384x640 2 objects, 60.0ms
# Speed: 1.7ms preprocess, 60.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'object'}
#  orig_img: array([[[ 30,  36,  31],
#          [ 40,  46,  41],
#          [ 47,  53,  48],
#          ...,
#          [ 14,  10,  21],
#          [ 12,   8,  19],
#          [ 11,   7,  18]],
#
#         [[ 34,  40,  35],
#          [ 38,  44,  39],
#          [ 40,  46,  41],
#          ...,
#          [ 18,  14,  25],
#          [ 16,  12,  23],
#          [ 15,  11,  22]],
#
#         [[ 39,  45,  40],
#          [ 37,  43,  38],
#          [ 34,  40,  35],
#          ...,
#          [ 19,  15,  27],
#          [ 18,  14,  26],
# ...

# %%
from PIL import Image

im1 = Image.open("./_97256115_mediaitem97256111.jpg")
results = model.predict(source=im1, save=True)
# Out:
# 0: 384x640 2 objects, 45.7ms
# Speed: 2.5ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/florian/projects/fh/mc/semester3/dnn/lab/runs/detect/predict

# %%
im1 = Image.open("./Three-Australian-Shepherd-puppies-sitting-in-a-field.jpg")
results = model.predict(source=im1, save=True)
# Out:
# 0: 448x640 (no detections), 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /home/florian/projects/fh/mc/semester3/dnn/lab/runs/detect/predict2

# %%
im1 = Image.open("./_methode_times_prod_web_bin_b743f1f2-bf27-11ec-8413-422ef6319ad0.jpg")
results = model.predict(source=im1, save=True)
# Out:
# 0: 384x640 61 objects, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/florian/projects/fh/mc/semester3/dnn/lab/runs/detect/predict3
